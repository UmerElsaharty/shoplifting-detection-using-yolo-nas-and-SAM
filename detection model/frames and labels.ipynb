# %%
import cv2
import os
import torch
import random

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

def extract_and_filter_frames(video_dir, output_dir, minority_class_dir, frames_to_sample=200, interval_seconds=5, frames_per_interval=25):
    # Create separate output directories for each class
    majority_output_dir = os.path.join(output_dir, 'non_shoplifting')
    minority_output_dir = os.path.join(output_dir, 'shoplifting')

    if not os.path.exists(majority_output_dir):
        os.makedirs(majority_output_dir)
    if not os.path.exists(minority_output_dir):
        os.makedirs(minority_output_dir)

    # List all video files
    all_majority_videos = [f for f in os.listdir(video_dir) if f.endswith((".mp4"))]
    all_minority_videos = [f for f in os.listdir(minority_class_dir) if f.endswith((".mp4"))]

    # Randomly sample videos from the minority class for oversampling
    sampled_minority_videos = random.sample(all_minority_videos, min(frames_to_sample, len(all_minority_videos)))

    # Limit the number of frames from the majority class
    max_frames_majority = len(sampled_minority_videos) * frames_per_interval  # Match minority frames

    # Process the majority class but limit the frames
    for video_file in all_majority_videos[:max_frames_majority // frames_per_interval]:
        video_path = os.path.join(video_dir, video_file)
        process_video(video_path, majority_output_dir, interval_seconds, frames_per_interval)

    # Oversample frames from the minority class (shoplifting)
    for video_file in sampled_minority_videos:
        video_path = os.path.join(minority_class_dir, video_file)
        process_video(video_path, minority_output_dir, interval_seconds, frames_per_interval)

def process_video(video_path, output_dir, interval_seconds, frames_per_interval):
    video_capture = cv2.VideoCapture(video_path)
    fps = int(video_capture.get(cv2.CAP_PROP_FPS))
    frames_to_skip = interval_seconds * fps
    count = 0
    success = True

    while success:
        video_capture.set(cv2.CAP_PROP_POS_FRAMES, count * frames_to_skip)

        for i in range(frames_per_interval):
            success, frame = video_capture.read()
            if not success:
                break

            # YOLOv5 person detection
            results = model(frame)

            # Get the labels of detected objects
            labels = results.pred[0][:, -1].cpu().numpy()  # Extract the labels from predictions
            classes = [results.names[int(label)] for label in labels]

            # Only save frames with 'person'
            if 'person' in classes:
                frame_path = os.path.join(output_dir, f"{os.path.basename(video_path)}_frame_{count}_{i}.jpg")
                cv2.imwrite(frame_path, frame)

        count += 1

    video_capture.release()

# Example usage
video_dir = '/kaggle/input/shop-dataset/Shop DataSet/non shop lifters'  # Majority class (non-shoplifters)
minority_class_dir = '/kaggle/input/shop-dataset/Shop DataSet/shop lifters'  # Minority class (shoplifters)
output_dir = 'filtered_frames_output_dir'

extract_and_filter_frames(video_dir, output_dir, minority_class_dir, frames_to_sample=200, interval_seconds=4, frames_per_interval=6)

# %%
import os

# Set the directory path
shoplifting_dir = '/kaggle/working/filtered_frames_output_dir/non_shoplifting'

# Get the number of files in the directory
num_files = len([f for f in os.listdir(shoplifting_dir) if os.path.isfile(os.path.join(shoplifting_dir, f))])

# Print the result
print(f"Number of files in shoplifting directory: {num_files}")
# Out:
# Number of files in shoplifting directory: 2806

# %%
import os

# Set the directory path
shoplifting_dir = '/kaggle/working/filtered_frames_output_dir/shoplifting'

# Get the number of files in the directory
num_files = len([f for f in os.listdir(shoplifting_dir) if os.path.isfile(os.path.join(shoplifting_dir, f))])

# Print the result
print(f"Number of files in shoplifting directory: {num_files}")
# Out:
# Number of files in shoplifting directory: 2918

# %%
# !zip -r file.zip /kaggle/working/filtered_frames_output_dir

# %%
import os
import cv2
import torch

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

def label_frames(frames_dir, labels_dir):
    """
    Function to label frames with YOLO format annotations and save them into a separate directory.

    Parameters:
    - frames_dir (str): Path to the directory containing frames.
    - labels_dir (str): Path to the directory to save corresponding YOLO annotation files.
    """

    # Ensure the labels directory exists
    if not os.path.exists(labels_dir):
        os.makedirs(labels_dir)

    # Loop through each frame in the frames directory
    for frame_filename in os.listdir(frames_dir):
        if frame_filename.endswith(('.jpg', '.png', '.jpeg')):
            frame_path = os.path.join(frames_dir, frame_filename)

            # Load frame
            frame = cv2.imread(frame_path)
            if frame is None:
                print(f"Error loading {frame_filename}, skipping.")
                continue

            # YOLOv5 person detection
            results = model(frame)

            # Get the labels and bounding boxes of detected objects
            labels = results.pred[0][:, -1].cpu().numpy()  # Class labels
            boxes = results.pred[0][:, :4].cpu().numpy()  # Bounding boxes
            classes = [results.names[int(label)] for label in labels]

            # Only save annotations if 'person' is detected
            if 'person' in classes:
                # Create corresponding YOLO annotation file
                txt_filename = frame_filename.replace('.jpg', '.txt').replace('.png', '.txt')
                txt_path = os.path.join(labels_dir, txt_filename)

                with open(txt_path, 'w') as f:
                    for i, cls in enumerate(classes):
                        if cls == 'person':
                            # YOLO format: <class> <x_center> <y_center> <width> <height>
                            box = boxes[i]
                            x_center = (box[0] + box[2]) / 2 / frame.shape[1]
                            y_center = (box[1] + box[3]) / 2 / frame.shape[0]
                            width = (box[2] - box[0]) / frame.shape[1]
                            height = (box[3] - box[1]) / frame.shape[0]

                            # Write annotation in YOLO format (class 0 for person)
                            f.write(f"0 {x_center} {y_center} {width} {height}\n")

                print(f"Saved annotation for {frame_filename}")
            else:
                print(f"No person detected in {frame_filename}")

# Example usage
frames_dir = '/kaggle/working/filtered_frames_output_dir/non_shoplifting'  
labels_dir = '/kaggle/working/non_shoplifting_labels'  

label_frames(frames_dir, labels_dir)

# %%
import os
import cv2
import torch

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

def label_frames(frames_dir, labels_dir):
    """
    Function to label frames with YOLO format annotations and save them into a separate directory.

    Parameters:
    - frames_dir (str): Path to the directory containing frames.
    - labels_dir (str): Path to the directory to save corresponding YOLO annotation files.
    """

    # Ensure the labels directory exists
    if not os.path.exists(labels_dir):
        os.makedirs(labels_dir)

    # Loop through each frame in the frames directory
    for frame_filename in os.listdir(frames_dir):
        if frame_filename.endswith(('.jpg', '.png', '.jpeg')):
            frame_path = os.path.join(frames_dir, frame_filename)

            # Load frame
            frame = cv2.imread(frame_path)
            if frame is None:
                print(f"Error loading {frame_filename}, skipping.")
                continue

            # YOLOv5 person detection
            results = model(frame)

            # Get the labels and bounding boxes of detected objects
            labels = results.pred[0][:, -1].cpu().numpy()  # Class labels
            boxes = results.pred[0][:, :4].cpu().numpy()  # Bounding boxes
            classes = [results.names[int(label)] for label in labels]

            # Only save annotations if 'person' is detected
            if 'person' in classes:
                # Create corresponding YOLO annotation file
                txt_filename = frame_filename.replace('.jpg', '.txt').replace('.png', '.txt')
                txt_path = os.path.join(labels_dir, txt_filename)

                with open(txt_path, 'w') as f:
                    for i, cls in enumerate(classes):
                        if cls == 'person':
                            # YOLO format: <class> <x_center> <y_center> <width> <height>
                            box = boxes[i]
                            x_center = (box[0] + box[2]) / 2 / frame.shape[1]
                            y_center = (box[1] + box[3]) / 2 / frame.shape[0]
                            width = (box[2] - box[0]) / frame.shape[1]
                            height = (box[3] - box[1]) / frame.shape[0]

                            # Write annotation in YOLO format (class 0 for person)
                            f.write(f"0 {x_center} {y_center} {width} {height}\n")

                print(f"Saved annotation for {frame_filename}")
            else:
                print(f"No person detected in {frame_filename}")

# Example usage
frames_dir = '/kaggle/working/filtered_frames_output_dir/shoplifting'  
labels_dir = '/kaggle/working/shoplifting_labels'  

label_frames(frames_dir, labels_dir)

# %%
import os
import cv2

def visualize_annotations(frames_dir, labels_dir, output_dir=None):
    """
    Visualize YOLO annotations by drawing bounding boxes on the images.

    Parameters:
    - frames_dir (str): Path to the directory containing frames.
    - labels_dir (str): Path to the directory containing YOLO annotation files.
    - output_dir (str): Optional path to save the annotated images. If not provided, images will be shown using OpenCV's imshow.
    """

    # Ensure the output directory exists if provided
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Loop through each frame in the frames directory
    for frame_filename in os.listdir(frames_dir):
        if frame_filename.endswith(('.jpg', '.png', '.jpeg')):
            frame_path = os.path.join(frames_dir, frame_filename)
            label_path = os.path.join(labels_dir, frame_filename.replace('.jpg', '.txt').replace('.png', '.txt'))

            # Load the image
            frame = cv2.imread(frame_path)
            if frame is None:
                print(f"Error loading {frame_filename}, skipping.")
                continue

            # Check if annotation file exists
            if not os.path.exists(label_path):
                print(f"No annotation for {frame_filename}, skipping.")
                continue

            # Read the annotation file
            with open(label_path, 'r') as f:
                lines = f.readlines()

            # Loop through each line in the annotation file
            for line in lines:
                # YOLO format: <class_id> <x_center> <y_center> <width> <height>
                class_id, x_center, y_center, width, height = map(float, line.strip().split())

                # Convert normalized YOLO coordinates back to image coordinates
                img_height, img_width, _ = frame.shape
                x_center *= img_width
                y_center *= img_height
                width *= img_width
                height *= img_height

                # Calculate the top-left and bottom-right corners of the bounding box
                x1 = int(x_center - width / 2)
                y1 = int(y_center - height / 2)
                x2 = int(x_center + width / 2)
                y2 = int(y_center + height / 2)

                # Draw the bounding box on the image (use green for 'person')
                color = (0, 255, 0)  # Green for 'person'
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

            # Save or display the annotated image
            if output_dir:
                output_path = os.path.join(output_dir, frame_filename)
                cv2.imwrite(output_path, frame)
                print(f"Annotated image saved at {output_path}")
            else:
                # Display the image
                cv2.imshow('Annotated Image', frame)
                cv2.waitKey(0)  # Wait for a key press to close the image window
                cv2.destroyAllWindows()

# Example usage
frames_dir = '/kaggle/working/filtered_frames_output_dir/shoplifting' 
labels_dir = '/kaggle/working/shoplifting_labels'  
output_dir = '/kaggle/working/shoplifting_labelss'  

visualize_annotations(frames_dir, labels_dir, output_dir)

# %%
# !zip -r label_file.zip /kaggle/working/non_shoplifting_labels

# %%
# !zip -r shoplifting_label_file.zip /kaggle/working/shoplifting_labels
# Out:
#   adding: kaggle/working/shoplifting_labels/ (stored 0%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_17.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_88.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_11.mp4_frame_0_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_93.mp4_frame_2_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_67.mp4_frame_0_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_68.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_88.mp4_frame_1_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_5.mp4_frame_0_5.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_18.mp4_frame_2_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_8.mp4_frame_2_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_113.mp4_frame_0_2.txt (deflated 31%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_11.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_15.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_36.mp4_frame_0_2.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_24.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_29.mp4_frame_1_5.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_1_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_43.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_24.mp4_frame_2_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_36.mp4_frame_4_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_17.mp4_frame_3_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_5.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_11.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_122.mp4_frame_0_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_23.mp4_frame_1_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_41.mp4_frame_4_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_13.mp4_frame_3_5.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_27.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_102.mp4_frame_1_3.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_13.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_99.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_92.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_46.mp4_frame_2_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_41.mp4_frame_0_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_33.mp4_frame_3_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_33.mp4_frame_1_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_51.mp4_frame_3_2.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_0.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_27.mp4_frame_2_0.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_17.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_0.mp4_frame_2_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_78.mp4_frame_2_5.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_57.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_85.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_24.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_33.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_11.mp4_frame_2_2.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_4_5.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_120.mp4_frame_2_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_107.mp4_frame_0_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_115.mp4_frame_1_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_33.mp4_frame_3_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_104.mp4_frame_0_3.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_110.mp4_frame_5_1.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_28.mp4_frame_0_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_36.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_90.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_28.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_41.mp4_frame_3_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_56.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_0.mp4_frame_3_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_14.mp4_frame_1_2.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_7.mp4_frame_1_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_72.mp4_frame_0_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_7.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_105.mp4_frame_2_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_22.mp4_frame_2_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_92.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_15.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_88.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_51.mp4_frame_1_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_94.mp4_frame_1_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_41.mp4_frame_4_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_53.mp4_frame_3_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_20.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_8.mp4_frame_1_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_91.mp4_frame_2_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_96.mp4_frame_0_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_85.mp4_frame_1_3.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_61.mp4_frame_2_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_19.mp4_frame_2_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_88.mp4_frame_2_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_5.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_91.mp4_frame_2_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_37.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_43.mp4_frame_4_1.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_85.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_8.mp4_frame_3_1.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_10.mp4_frame_2_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_46.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_53.mp4_frame_2_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_42.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_42.mp4_frame_3_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_26.mp4_frame_3_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_10.mp4_frame_1_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_28.mp4_frame_0_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_31.mp4_frame_2_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_19.mp4_frame_0_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_18.mp4_frame_3_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_113.mp4_frame_0_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_100.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_126.mp4_frame_3_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_86.mp4_frame_2_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_67.mp4_frame_3_5.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_69.mp4_frame_2_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_110.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_29.mp4_frame_1_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_24.mp4_frame_3_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_2.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_9.mp4_frame_2_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_49.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_41.mp4_frame_1_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_34.mp4_frame_0_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_5.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_97.mp4_frame_2_3.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_53.mp4_frame_2_4.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_27.mp4_frame_1_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_111.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_67.mp4_frame_2_1.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_43.mp4_frame_1_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_9.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_62.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_26.mp4_frame_0_4.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_4_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_43.mp4_frame_4_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_108.mp4_frame_2_4.txt (deflated 47%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_46.mp4_frame_3_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_101.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_44.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_15.mp4_frame_1_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_89.mp4_frame_3_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_3.mp4_frame_2_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_1.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_48.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_6.mp4_frame_0_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_92.mp4_frame_0_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_11.mp4_frame_1_3.txt (deflated 48%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_1.mp4_frame_2_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_85.mp4_frame_2_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_17.mp4_frame_2_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_65.mp4_frame_1_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_66.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_52.mp4_frame_1_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_23.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_8.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_48.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_21.mp4_frame_3_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_11.mp4_frame_2_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_4.mp4_frame_2_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_18.mp4_frame_3_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_4.mp4_frame_0_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_5.mp4_frame_0_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_8.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_37.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_17.mp4_frame_1_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_39.mp4_frame_1_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_4.mp4_frame_1_5.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_17.mp4_frame_1_3.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_81.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_66.mp4_frame_2_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_104.mp4_frame_0_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_11.mp4_frame_3_3.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_89.mp4_frame_1_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_25.mp4_frame_1_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_33.mp4_frame_1_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_43.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_99.mp4_frame_1_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_17.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_9.mp4_frame_2_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_8.mp4_frame_2_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_7.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_90.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_1.mp4_frame_0_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_52.mp4_frame_0_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_15.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_5_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_99.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_71.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_20.mp4_frame_2_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_5.mp4_frame_3_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_27.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_50.mp4_frame_1_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_5.mp4_frame_2_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_20.mp4_frame_1_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_47.mp4_frame_1_4.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_40.mp4_frame_4_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_99.mp4_frame_3_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_39.mp4_frame_0_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_20.mp4_frame_2_3.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_26.mp4_frame_1_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_2.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_91.mp4_frame_2_5.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_101.mp4_frame_1_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_4_5.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_22.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_51.mp4_frame_3_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_11.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_40.mp4_frame_4_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_36.mp4_frame_3_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_127.mp4_frame_3_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_60.mp4_frame_1_4.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_0.mp4_frame_2_3.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_13.mp4_frame_1_5.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_36.mp4_frame_2_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_8.mp4_frame_1_5.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_27.mp4_frame_1_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_26.mp4_frame_0_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_43.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_69.mp4_frame_1_2.txt (deflated 45%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_109.mp4_frame_0_2.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_22.mp4_frame_2_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_19.mp4_frame_1_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_19.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_26.mp4_frame_1_2.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_50.mp4_frame_1_0.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_10.mp4_frame_1_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_20.mp4_frame_4_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_5.mp4_frame_1_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_4.mp4_frame_1_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_17.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_52.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_125.mp4_frame_0_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_86.mp4_frame_2_3.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_104.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_5_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_5.mp4_frame_3_3.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_20.mp4_frame_2_4.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_36.mp4_frame_2_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_45.mp4_frame_0_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_53.mp4_frame_1_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_11.mp4_frame_2_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_16.mp4_frame_1_2.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_43.mp4_frame_2_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_48.mp4_frame_3_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_101.mp4_frame_2_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_5.mp4_frame_0_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_19.mp4_frame_1_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_8.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_67.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_43.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_56.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_25.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_41.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_70.mp4_frame_1_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_46.mp4_frame_1_5.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_0.mp4_frame_2_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_64.mp4_frame_1_2.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_93.mp4_frame_1_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_115.mp4_frame_3_1.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_19.mp4_frame_1_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_0.mp4_frame_3_0.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_0_3.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_96.mp4_frame_0_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_91.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_4.mp4_frame_0_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_97.mp4_frame_4_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_11.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_94.mp4_frame_0_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_52.mp4_frame_1_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_74.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_98.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_37.mp4_frame_2_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_46.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_11.mp4_frame_1_2.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_18.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_13.mp4_frame_1_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_39.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_23.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_93.mp4_frame_1_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_89.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_2.mp4_frame_2_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_57.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_14.mp4_frame_2_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_81.mp4_frame_1_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_122.mp4_frame_0_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_71.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_64.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_3_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_113.mp4_frame_3_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_22.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_89.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_15.mp4_frame_0_5.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_27.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_67.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_88.mp4_frame_3_2.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_3_5.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_0_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_21.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_0.mp4_frame_3_1.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_14.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_26.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_19.mp4_frame_1_3.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_17.mp4_frame_3_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_21.mp4_frame_1_0.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_89.mp4_frame_4_0.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_85.mp4_frame_3_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_50.mp4_frame_1_1.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_120.mp4_frame_2_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_93.mp4_frame_1_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_27.mp4_frame_0_4.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_55.mp4_frame_0_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_34.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_32.mp4_frame_1_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_20.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_11.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_5.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_7.mp4_frame_2_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_96.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_0.mp4_frame_2_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_2_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_43.mp4_frame_1_2.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_113.mp4_frame_2_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_8.mp4_frame_1_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_125.mp4_frame_0_3.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_116.mp4_frame_0_2.txt (deflated 45%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_10.mp4_frame_3_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_2.mp4_frame_1_4.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_70.mp4_frame_1_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_65.mp4_frame_1_0.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_35.mp4_frame_3_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_78.mp4_frame_1_4.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_26.mp4_frame_1_5.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_19.mp4_frame_1_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_100.mp4_frame_0_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_51.mp4_frame_3_5.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_5.mp4_frame_1_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_16.mp4_frame_2_1.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_39.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_43.mp4_frame_2_2.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_89.mp4_frame_1_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_102.mp4_frame_4_3.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_37.mp4_frame_2_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_2_1.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_35.mp4_frame_1_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_52.mp4_frame_2_2.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_0.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_39.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_15.mp4_frame_1_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_92.mp4_frame_2_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_71.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_19.mp4_frame_2_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_41.mp4_frame_4_5.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_99.mp4_frame_0_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_70.mp4_frame_2_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_1_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_0.mp4_frame_1_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_0_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_21.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_26.mp4_frame_2_2.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_29.mp4_frame_1_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_21.mp4_frame_1_3.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_20.mp4_frame_2_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_0.mp4_frame_2_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_111.mp4_frame_1_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_89.mp4_frame_1_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_56.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_52.mp4_frame_2_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_18.mp4_frame_2_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_101.mp4_frame_2_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_36.mp4_frame_3_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_12.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_90.mp4_frame_3_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_18.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_15.mp4_frame_3_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_10.mp4_frame_3_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_11.mp4_frame_1_4.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_77.mp4_frame_2_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_9.mp4_frame_1_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_42.mp4_frame_4_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_91.mp4_frame_1_0.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_43.mp4_frame_1_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_4.mp4_frame_1_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_40.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_51.mp4_frame_1_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_20.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_4_4.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_21.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_110.mp4_frame_4_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_22.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_46.mp4_frame_3_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_102.mp4_frame_0_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_98.mp4_frame_3_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_8.mp4_frame_1_4.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_15.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_10.mp4_frame_3_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_19.mp4_frame_0_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_88.mp4_frame_3_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_28.mp4_frame_1_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_36.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_44.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_117.mp4_frame_2_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_16.mp4_frame_3_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_4_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_33.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_115.mp4_frame_2_0.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_39.mp4_frame_1_2.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_45.mp4_frame_1_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_5.mp4_frame_0_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_26.mp4_frame_0_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_9.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_15.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_2_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_52.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_18.mp4_frame_2_1.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_34.mp4_frame_0_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_20.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_42.mp4_frame_1_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_48.mp4_frame_2_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_18.mp4_frame_1_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_43.mp4_frame_1_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_46.mp4_frame_3_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_1.mp4_frame_2_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_8.mp4_frame_2_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_48.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_28.mp4_frame_3_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_18.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_64.mp4_frame_2_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_28.mp4_frame_2_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_20.mp4_frame_3_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_23.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_2.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_51.mp4_frame_1_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_0.mp4_frame_3_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_86.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_43.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_23.mp4_frame_2_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_22.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_21.mp4_frame_0_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_97.mp4_frame_4_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_4_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_92.mp4_frame_1_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_4_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_109.mp4_frame_3_1.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_42.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_43.mp4_frame_1_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_17.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_100.mp4_frame_0_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_19.mp4_frame_3_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_100.mp4_frame_2_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_39.mp4_frame_0_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_37.mp4_frame_2_2.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_110.mp4_frame_5_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_20.mp4_frame_3_4.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_0.mp4_frame_2_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_11.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_28.mp4_frame_3_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_6.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_121.mp4_frame_2_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_22.mp4_frame_3_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_9.mp4_frame_2_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_117.mp4_frame_3_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_22.mp4_frame_3_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_115.mp4_frame_2_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_28.mp4_frame_3_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_98.mp4_frame_0_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_21.mp4_frame_4_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_19.mp4_frame_1_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_51.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_89.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_102.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_120.mp4_frame_3_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_3_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_98.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_36.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_116.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_9.mp4_frame_2_2.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_110.mp4_frame_3_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_91.mp4_frame_4_5.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_69.mp4_frame_1_3.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_17.mp4_frame_1_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_104.mp4_frame_2_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_91.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_88.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_18.mp4_frame_2_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_53.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_19.mp4_frame_0_2.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_67.mp4_frame_0_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_8.mp4_frame_2_2.txt (deflated 43%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_10.mp4_frame_0_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_94.mp4_frame_0_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_19.mp4_frame_0_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_65.mp4_frame_1_2.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_41.mp4_frame_3_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_2_3.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_63.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_88.mp4_frame_2_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_0.mp4_frame_0_5.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_65.mp4_frame_3_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_10.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_71.mp4_frame_1_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_58.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_22.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_31.mp4_frame_3_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_18.mp4_frame_3_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_6.mp4_frame_1_0.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_11.mp4_frame_2_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_60.mp4_frame_2_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_8.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_5.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_62.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_85.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_0.mp4_frame_3_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_89.mp4_frame_0_1.txt (deflated 26%)
# ...
#   adding: kaggle/working/shoplifting_labels/videppppsss_16.mp4_frame_3_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_85.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_88.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_15.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_64.mp4_frame_2_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_121.mp4_frame_1_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_109.mp4_frame_1_4.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_94.mp4_frame_0_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_23.mp4_frame_2_4.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_24.mp4_frame_0_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_0_3.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_50.mp4_frame_2_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_93.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_18.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_62.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_77.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_10.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_0.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_12.mp4_frame_0_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_101.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_39.mp4_frame_3_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_48.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_102.mp4_frame_3_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_18.mp4_frame_2_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_101.mp4_frame_1_3.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_8.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_56.mp4_frame_2_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_52.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_15.mp4_frame_3_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_43.mp4_frame_4_3.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_2.mp4_frame_1_1.txt (deflated 31%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_19.mp4_frame_1_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_46.mp4_frame_2_0.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_18.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_31.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_17.mp4_frame_1_1.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_33.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_68.mp4_frame_2_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_0.mp4_frame_1_5.txt (deflated 23%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_68.mp4_frame_1_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_20.mp4_frame_4_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_24.mp4_frame_3_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_5.mp4_frame_3_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_10.mp4_frame_3_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_4_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_51.mp4_frame_3_0.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_4_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_89.mp4_frame_3_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_57.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_35.mp4_frame_1_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_35.mp4_frame_1_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_19.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_88.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_35.mp4_frame_0_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_9.mp4_frame_2_5.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_54.mp4_frame_1_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_20.mp4_frame_3_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_36.mp4_frame_0_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_97.mp4_frame_0_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_0.mp4_frame_3_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_17.mp4_frame_0_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_48.mp4_frame_1_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_11.mp4_frame_2_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_53.mp4_frame_2_3.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_39.mp4_frame_0_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_84.mp4_frame_1_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_10.mp4_frame_1_2.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_26.mp4_frame_0_3.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_5.mp4_frame_1_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_11.mp4_frame_3_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_125.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_1.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_52.mp4_frame_1_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_28.mp4_frame_0_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_52.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_111.mp4_frame_1_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_18.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_53.mp4_frame_2_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_6.mp4_frame_2_4.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_91.mp4_frame_3_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_28.mp4_frame_0_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_24.mp4_frame_2_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_22.mp4_frame_3_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_90.mp4_frame_3_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_116.mp4_frame_2_1.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_53.mp4_frame_3_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_21.mp4_frame_2_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_37.mp4_frame_2_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_0.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_14.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_2_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_43.mp4_frame_2_4.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_18.mp4_frame_1_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_23.mp4_frame_1_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_19.mp4_frame_2_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_122.mp4_frame_0_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_88.mp4_frame_2_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_15.mp4_frame_2_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_37.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_99.mp4_frame_0_2.txt (deflated 40%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_4_2.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_35.mp4_frame_3_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_26.mp4_frame_3_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_117.mp4_frame_4_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_32.mp4_frame_1_1.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_0.mp4_frame_3_2.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_91.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_127.mp4_frame_1_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_2_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_19.mp4_frame_1_0.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_3.mp4_frame_1_2.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_15.mp4_frame_0_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_91.mp4_frame_1_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_17.mp4_frame_4_0.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_25.mp4_frame_1_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_28.mp4_frame_0_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_0.mp4_frame_3_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_120.mp4_frame_4_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_0.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_19.mp4_frame_0_1.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_5.mp4_frame_1_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_39.mp4_frame_1_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_54.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_50.mp4_frame_2_1.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_26.mp4_frame_2_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_98.mp4_frame_0_2.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_127.mp4_frame_1_1.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_50.mp4_frame_2_2.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_121.mp4_frame_0_1.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_20.mp4_frame_4_0.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_17.mp4_frame_1_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_1.mp4_frame_2_4.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_4.mp4_frame_2_5.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_16.mp4_frame_2_2.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_108.mp4_frame_1_4.txt (deflated 48%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_67.mp4_frame_1_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_51.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_97.mp4_frame_1_2.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_118.mp4_frame_4_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_53.mp4_frame_3_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_33.mp4_frame_1_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_7.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_18.mp4_frame_3_5.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_45.mp4_frame_0_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyynnnnnnzzzzzyyyss_23.mp4_frame_0_5.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_85.mp4_frame_2_1.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_2_1.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_11.mp4_frame_3_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_0.mp4_frame_2_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videmmmmmmsss_98.mp4_frame_2_4.txt (deflated 26%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_91.mp4_frame_4_4.txt (deflated 41%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_36.mp4_frame_2_0.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_23.mp4_frame_2_4.txt (deflated 24%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_58.mp4_frame_1_0.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_8.mp4_frame_2_0.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_0.mp4_frame_1_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_86.mp4_frame_2_4.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_15.mp4_frame_0_5.txt (deflated 29%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_127.mp4_frame_0_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyzzzzzyyyss_19.mp4_frame_2_2.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_8.mp4_frame_3_0.txt (deflated 42%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_2_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_48.mp4_frame_3_3.txt (deflated 28%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_7.mp4_frame_2_0.txt (deflated 25%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_126.mp4_frame_3_4.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/shop_lifter_38.mp4_frame_0_0.txt (deflated 30%)
#   adding: kaggle/working/shoplifting_labels/videyyyyyyyyyss_56.mp4_frame_1_5.txt (deflated 27%)
#   adding: kaggle/working/shoplifting_labels/videppppsss_24.mp4_frame_1_0.txt (deflated 26%)
